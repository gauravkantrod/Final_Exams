# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#f0f0f0;">..............................................
#     <span style="font-family: Arial; font-weight:bold;font-size:3.2em;color:#c7920e;">NPV EXAM FOR 70 MARKS

# %% [markdown]
# -------------

# %% [markdown]
# # 4 Questions X  5 Marks = 20 Marks

# %% [markdown]
# ---------

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">1. Read the dataset(matches.csv) and Answer below questions
#
#    1. Display the no.of matches played in the dataset?
#    2. What percentages of match are won by the toss winners?
#    3. Who won the final match and also which two teams reached the finals match?
#    4. Create a dataframe of the team who have won the match after winning toss?
#    5. What percentage of matches are won after selecting from the toss_decision as a field?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_rows', 1000)

# %%
matches = pd.read_csv('matches.csv')

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
matches.shape
# Out:
# (636, 18)

# %% [markdown]
# ####  1. Display the no.of matches played in the dataset?

# %%
print('Number of matched played in dataset is --',matches.shape[0])
# Out:
# Number of matched played in dataset is -- 636

# %% [markdown]
# #### 2.What percentages of match are won by the toss winners?

# %%
won_toss_match_percentage = 100*matches[matches['toss_winner'] == matches['winner']]['winner'].count()/matches.shape[0]

# %%
print('Percentage of matches won by toss winner are -- ', won_toss_match_percentage,'%')
# Out:
# Percentage of matches won by toss winner are --  51.100628930817614 %

# %% [markdown]
# #### 3.Who won the final match and also which two teams reached the finals match?

# %%
print('Final match is won by --- ',matches.iloc[635:,:]['winner'])
# Out:
# Final match is won by ---  635    Sunrisers Hyderabad
# Name: winner, dtype: object

# %%
print('Final teams are --- ',matches.iloc[635:,:]['team1'],matches.iloc[635:,:]['team2'])
# Out:
# Final teams are ---  635    Sunrisers Hyderabad
# Name: team1, dtype: object 635    Royal Challengers Bangalore
# Name: team2, dtype: object

# %% [markdown]
# #### 4. Create a dataframe of the team who have won the match after winning toss?

# %%
match_won_after_toss = matches[matches['toss_winner'] == matches['winner']]

# %%
match_won_after_toss.head()
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# #### 5. What percentage of matches are won after selecting from the toss_decision as a field?

# %%
100*match_won_after_toss[(match_won_after_toss['toss_decision'] == 'field')]['toss_decision'].count()/matches.shape[0]
# Out:
# 31.60377358490566

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">2. Read the dataset(911.csv) and Answer below questions
#
#    1. Find the Top most zipcodes and townships (twp) for 911 calls?
#    2. There are EMS, Fire, and TrafficMake you need to separate column to create a new column called "Reason" and understand our data more?
#    3. What are the most common Reason for a 911 call ?
#    4. Change the timeStamp from strings to DateTime objects and also grab specific attributes(For example: Hour, Month and Day of the Week) from a Datetime object.
#    5. Restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week?

# %%
df_911 = pd.read_csv('911.csv')

# %%
df_911.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
df_911.tail()
# Out:
#               lat        lng  \
# 423904  40.139993 -75.049864
# 423905  40.270121 -75.382825
# 423906  40.270121 -75.382825
# 423907  40.190946 -75.237285
# 423908  40.155164 -75.264665
#
#                                                      desc      zip  \
# 423904  BUCK RD & WOODWARD DR; LOWER MORELAND; 2018-11...  19006.0
# 423905  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423906  OAK DR & MOYER RD; LOWER SALFORD; 2018-11-16 @...  19438.0
# 423907  SUMNEYTOWN PIKE & WELLINGTON DR; LOWER GWYNEDD...  19002.0
# 423908   HOFFMAN  ; LOWER GWYNEDD; 2018-11-16 @ 08:46:25;  19422.0
#
#                               title            timeStamp             twp  \
# 423904  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:54:08  LOWER MORELAND
# 423905  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:53:32   LOWER SALFORD
# 423906  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:54:19   LOWER SALFORD
# 423907  Traffic: VEHICLE ACCIDENT -  2018-11-16 08:51:48   LOWER GWYNEDD
# ...

# %%
df_911.shape
# Out:
# (423909, 9)

# %%
df_911.dtypes
# Out:
# lat          float64
# lng          float64
# desc          object
# zip          float64
# title         object
# timeStamp     object
# twp           object
# addr          object
# e              int64
# dtype: object

# %%
100*df_911.isnull().sum()/df_911.shape[0]
# Out:
# lat           0.000000
# lng           0.000000
# desc          0.000000
# zip          12.297215
# title         0.000000
# timeStamp     0.000000
# twp           0.037508
# addr          0.000000
# e             0.000000
# dtype: float64

# %% [markdown]
# #### 1. Find the Top 1 zipcodes and townships (twp) for 911 calls?

# %%
df_911.groupby(['zip','twp'])['zip'].max()
# Out:
# zip      twp
# 3366.0   TRAPPE              3366.0
# 7203.0   UPPER DUBLIN        7203.0
# 8033.0   LOWER MERION        8033.0
# 8065.0   NEW HANOVER         8065.0
# 8361.0   LOWER SALFORD       8361.0
#                              ...
# 19607.0  WHITPAIN           19607.0
# 21701.0  UPPER FREDERICK    21701.0
# 23005.0  UPPER MERION       23005.0
# 36107.0  MONTGOMERY         36107.0
# 77316.0  MONTGOMERY         77316.0
# Name: zip, Length: 732, dtype: float64

# %% [markdown]
# #### 2. There are EMS, Fire, and TrafficMake you need to separate column to create a new column called "Reason" and understand our data more?

# %%
df_911['reason'] = df_911['title'].apply(lambda x : x.split(':')[0])

# %%
df_911['reason'].head()
# Out:
# 0     EMS
# 1     EMS
# 2    Fire
# 3     EMS
# 4     EMS
# Name: reason, dtype: object

# %% [markdown]
# #### 3. What are the most common Reason for a 911 call ?

# %%
df_911['title'].value_counts()
# Out:
# Traffic: VEHICLE ACCIDENT -    98401
# Traffic: DISABLED VEHICLE -    31871
# Fire: FIRE ALARM               24380
# EMS: FALL VICTIM               21253
# EMS: RESPIRATORY EMERGENCY     21158
#                                ...
# EMS: VEHICLE LEAKING FUEL          1
# Fire: POISONING                    1
# Fire: DIABETIC EMERGENCY           1
# EMS: PUBLIC SERVICE                1
# Fire: UNCONSCIOUS SUBJECT          1
# Name: title, Length: 141, dtype: int64

# %% [markdown]
# #### 4.Change the timeStamp from strings to DateTime objects and also grab specific attributes(For example: Hour, Month and Day of the Week) from a Datetime object.

# %%
df_911['timeStamp'] = pd.to_datetime(df_911['timeStamp'])

# %%
df_911['timeStamp'].head()
# Out:
# 0   2015-12-10 17:10:52
# 1   2015-12-10 17:29:21
# 2   2015-12-10 14:39:21
# 3   2015-12-10 16:47:36
# 4   2015-12-10 16:56:52
# Name: timeStamp, dtype: datetime64[ns]

# %% [markdown]
# #### 5. Restructure the dataframe so that the columns become the Hours and the Index becomes the Day of the Week?

# %%
from datetime import date

# %%
df_911['Hours'] = df_911['timeStamp'].apply(lambda x : x.split())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-257eac052399> in <module>
# ----> 1 df_911['Hours'] = df_911['timeStamp'].apply(lambda x : x.split())
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-105-257eac052399> in <lambda>(x)
# ----> 1 df_911['Hours'] = df_911['timeStamp'].apply(lambda x : x.split())
#
# AttributeError: 'Timestamp' object has no attribute 'split'

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">3. Read the dataset(GlobalTemperatures.csv) and Answer below questions?
#
#
#    1. Set the date column as a DateTimeIndex and sort it?
#    2. Resample annually and rename index & columns?
#    3. Calculate the global baseline temperature?
#    4. Create the new "temperature anomaly" column (['AnnualAverageTemp'] - global_ref_temp)?
#    5. Drop the "AnnualAverageTemp" because you created new column name "Temperature Anomaly"?

# %%
temp = pd.read_csv('GlobalTemperatures.csv')

# %%
temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
temp.tail()
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
#       LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 3187              20.699                          0.110               9.005
# 3188              18.845                          0.088               7.199
# 3189              16.450                          0.059               5.232
# 3190              12.892                          0.093               2.157
# 3191              10.725                          0.154               0.287
#
# ...

# %%
temp.dtypes
# Out:
# dt                                                   object
# LandAverageTemperature                              float64
# LandAverageTemperatureUncertainty                   float64
# LandMaxTemperature                                  float64
# LandMaxTemperatureUncertainty                       float64
# LandMinTemperature                                  float64
# LandMinTemperatureUncertainty                       float64
# LandAndOceanAverageTemperature                      float64
# LandAndOceanAverageTemperatureUncertainty           float64
# DateTimeIndex                                datetime64[ns]
# year                                                 object
# dtype: object

# %%
100*temp.isnull().sum()/temp.shape[0]
# Out:
# dt                                            0.000000
# LandAverageTemperature                        0.375940
# LandAverageTemperatureUncertainty             0.375940
# LandMaxTemperature                           37.593985
# LandMaxTemperatureUncertainty                37.593985
# LandMinTemperature                           37.593985
# LandMinTemperatureUncertainty                37.593985
# LandAndOceanAverageTemperature               37.593985
# LandAndOceanAverageTemperatureUncertainty    37.593985
# DateTimeIndex                                 0.000000
# year                                          0.000000
# dtype: float64

# %% [markdown]
# #### 1. Set the date column as a DateTimeIndex and sort it?

# %%
temp['DateTimeIndex'] = pd.DatetimeIndex(temp['dt'])

# %%
temp['DateTimeIndex'].head()
# Out:
# 0   1750-01-01
# 1   1750-02-01
# 2   1750-03-01
# 3   1750-04-01
# 4   1750-05-01
# Name: DateTimeIndex, dtype: datetime64[ns]

# %% [markdown]
# #### 2. Write a code to convert from yyyy-mm-dd to yyyy?

# %%
temp['year'] = temp['dt'].apply(lambda x : x.split('-')[0])

# %%
temp['year'].head()
# Out:
# 0    1750
# 1    1750
# 2    1750
# 3    1750
# 4    1750
# Name: year, dtype: object

# %% [markdown]
# #### 3.Calculate the global baseline temperature on (1951 to 1980)

# %%
temp['year'] = temp['year'].astype(int)

# %%
temp_1951_1980 = temp[(temp['year'] >= 1952) & (temp['year'] <= 1980)]

# %%
global_ref_temp = temp_1951_1980['LandAndOceanAverageTemperature'].sum ()/temp_1951_1980.shape[0]

# %%
global_ref_temp = round(global_ref_temp,2)
global_ref_temp
# Out:
# 15.3

# %% [markdown]
# #### 4. Create the new "temperature anomaly" column (['AnnualAverageTemp'] - global_ref_temp)?

# %%
temp['temperature_anomaly'] = temp['LandAndOceanAverageTemperature'] - global_ref_temp

# %% [markdown]
# #### 5. Drop the "AnnualAverageTemp" becuse you created new column name "Temperature Anomaly"?

# %%
temp.drop('LandAndOceanAverageTemperature', axis = 1, inplace = True)

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">4. Read the dataset(Ecommerce_Purchases.csv) and Answer below questions?
#
#    1. What were the highest and lowest purchase prices?
#    2. How many people have English 'en' as their Language of choice on the website?
#    3. How many people have the job title of "Lawyer" ?
#    4. How many people made the purchase during the AM and how many people made the purchase during PM ?
#    5. Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?

# %%
ecomm = pd.read_csv('Ecommerce_Purchases.csv')

# %%
ecomm.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecomm.tail()
# Out:
#                                                 Address    Lot AM or PM  \
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9995  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/5352 ...
# 9996  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 9997  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 9998  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_8;...
# 9999  Mozilla/5.0 (X11; Linux i686; rv:1.9.5.20) Gec...
#
#                        Company       Credit Card CC Exp Date  \
# 9995             Randall-Sloan   342945015358701       03/22
# 9996  Hale, Collins and Wilson   210033169205009       07/25
# ...

# %%
ecomm.shape
# Out:
# (10000, 14)

# %%
100*ecomm.isnull().sum()/ecomm.shape[0]
# Out:
# Address             0.0
# Lot                 0.0
# AM_or_PM            0.0
# Browser_Info        0.0
# Company             0.0
# Credit_Card         0.0
# CC_Exp_Date         0.0
# CC_Security_Code    0.0
# CC_Provider         0.0
# Email               0.0
# Job                 0.0
# IP_Address          0.0
# Language            0.0
# Purchase_Price      0.0
# dtype: float64

# %% [markdown]
# #### 1. What were the highest and lowest purchase prices?

# %%
print('Highest purchase price is -- ',ecomm['Purchase_Price'].max())
# Out:
# Highest purchase price is --  99.99

# %%
print('Lowest purchase price is -- ',ecomm['Purchase_Price'].min())
# Out:
# Lowest purchase price is --  0.0

# %% [markdown]
# #### 2. How many people have English 'en' as their Language of choice on the website?

# %%
(ecomm['Language'] == 'en').sum()
# Out:
# 1098

# %% [markdown]
# #### 3. How many people have the job title of "Lawyer" ?

# %%
(ecomm['Job'] == 'Lawyer').sum()
# Out:
# 30

# %% [markdown]
# #### 4. How many people made the purchase during the AM and how many people made the purchase during PM ?

# %%
(ecomm['AM_or_PM'] == 'AM').sum()
# Out:
# 4932

# %%
(ecomm['AM_or_PM'] == 'PM').sum()
# Out:
# 5068

# %% [markdown]
# #### 5. Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction?

# %%
ecomm[ecomm['Lot'] == '90 WT']['Purchase_Price']
# Out:
# 513    75.1
# Name: Purchase_Price, dtype: float64

# %% [markdown]
# -----------

# %% [markdown]
# #  2 Questions X  10 Marks = 20 Marks

# %% [markdown]
# -------------

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">1. Read the dataset(YOUTUBE.csv) and Answer below questions?
#
#    1. Find out the top 5 categories with maximum number of videos uploaded and also find out the top 10 rated videos ?
#
#    2. Find out the 10 most viewed videos and also find the top 5 which video having the most of comments and count?

# %%
youtube = pd.read_csv("youtube.csv", names = ['v_id', 'v_uploader', 'v_interval', 'v_category', 'v_length', 'views_count', 'v_rating', 'no_ratings_given', 'comments_count', 'v_ids_related','v_ids_related_1','v_ids_related_2','v_ids_related_3','v_ids_related_4','v_ids_related_5','v_ids_related_6','v_ids_related_7','v_ids_related_8','v_ids_related_9','v_ids_related_10','v_ids_related_11','v_ids_related_12','v_ids_related_13','v_ids_related_14'], delimiter = '\t', header = None)
youtube.head()
# Out:
#           v_id            v_uploader  v_interval      v_category  v_length  \
# 0  QuRYeRnAuXM  EvilSquirrelPictures      1135.0  Pets & Animals     252.0
# 1  3TYqkBJ9YRk                hggh22      1135.0          Comedy     169.0
# 2  rSJ8QZWBegU               TimeGem      1135.0   Entertainment      95.0
# 3  nRcovJn9xHg            wooochacha      1135.0   Entertainment     118.0
# 4  UEvVksP91kg              johnx113      1135.0   Entertainment      83.0
#
#    views_count  v_rating  no_ratings_given  comments_count v_ids_related  ...  \
# 0       1075.0      4.96              46.0            86.0   gFa1YMEJFag  ...
# 1        228.0      5.00               5.0             3.0   QuRYeRnAuXM  ...
# 2        356.0      4.31              13.0             1.0   QuRYeRnAuXM  ...
# 3       1115.0      2.23              57.0            73.0   QuRYeRnAuXM  ...
# 4        281.0      2.67               9.0            16.0   gFa1YMEJFag  ...
#
# ...

# %%
youtube.tail()
# Out:
#              v_id       v_uploader  v_interval     v_category  v_length  \
# 4095  esCvu46qDaA            RSMFD       863.0  Entertainment      63.0
# 4096  kOZ8bRAO7YQ    RockstarGames         0.0           UNA       63.0
# 4097  GSsVZcKHues          GTASite      1024.0  Entertainment     123.0
# 4098  foKRqJGcbPQ  scrambledeggsTV      1100.0  Entertainment     136.0
# 4099  -CYhSNHbeC8          rehab07       771.0  Entertainment     186.0
#
#       views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# 4095     116929.0      4.84             182.0           222.0   8t4m5JM5r6Y
# 4096     199361.0      4.79            1256.0          2410.0           NaN
# 4097     486752.0      4.86            1098.0          1764.0   TecLbWk8A3w
# 4098      13115.0      4.45              33.0            37.0   LzI9VyIjpDI
# 4099     103556.0      4.30             277.0           220.0   wtVeF5bT6YQ
#
# ...

# %%
youtube.columns
# Out:
# Index(['v_id', 'v_uploader', 'v_interval', 'v_category', 'v_length',
#        'views_count', 'v_rating', 'no_ratings_given', 'comments_count',
#        'v_ids_related', 'v_ids_related_1', 'v_ids_related_2',
#        'v_ids_related_3', 'v_ids_related_4', 'v_ids_related_5',
#        'v_ids_related_6', 'v_ids_related_7', 'v_ids_related_8',
#        'v_ids_related_9', 'v_ids_related_10', 'v_ids_related_11',
#        'v_ids_related_12', 'v_ids_related_13', 'v_ids_related_14'],
#       dtype='object')

# %%
100*youtube.isnull().sum()/youtube.shape[0]
# Out:
# v_id                 0.000000
# v_uploader           0.829268
# v_interval           0.829268
# v_category           0.829268
# v_length             0.829268
# views_count          0.829268
# v_rating             0.829268
# no_ratings_given     0.829268
# comments_count       0.829268
# v_ids_related       21.000000
# v_ids_related_1     21.000000
# v_ids_related_2     21.024390
# v_ids_related_3     21.024390
# v_ids_related_4     21.024390
# v_ids_related_5     21.317073
# v_ids_related_6     21.536585
# v_ids_related_7     21.536585
# v_ids_related_8     22.317073
# v_ids_related_9     22.317073
# v_ids_related_10    22.317073
# v_ids_related_11    22.317073
# v_ids_related_12    22.439024
# v_ids_related_13    22.439024
# v_ids_related_14    36.390244
# dtype: float64

# %%
youtube.shape
# Out:
# (4100, 24)

# %% [markdown]
# #### 1. Find out the top 5 categories with maximum number of videos uploaded and also find out the top 10 rated videos ?

# %%
df_cat = youtube['v_category'].value_counts().to_frame()
df_cat.iloc[0:5]
# Out:
#                  v_category
# Entertainment           908
# Music                   862
# Comedy                  414
# People & Blogs          398
# News & Politics         333

# %%
df_top_10_rating = youtube.sort_values(by='v_rating',ascending=False).head(10)
df_top_10_rating
# Out:
#              v_id        v_uploader  v_interval            v_category  \
# 1440  7McDe1sdPlU      RemixedKingz      1022.0                 Music
# 3123  Uc-OWFYNry8        athletic46      1076.0                Sports
# 3086  _sBRIaZWpXE         theevang1      1112.0        People & Blogs
# 3085  hB92X7DIzvc         theevang1      1115.0      Film & Animation
# 3084  cvd-OyHm9lE         theevang1      1107.0                 Music
# 3083  TE8fKitNOKs         theevang1      1121.0        People & Blogs
# 3082  4odzrZHgsKI         theevang1      1121.0        People & Blogs
# 528   rxdvasZiZ2A      Astroranagun      1128.0  Science & Technology
# 529   7Rgz8doVQXg  usethistocomment      1087.0         Howto & Style
# 3081  OVrqKQ54_hI         theevang1      1107.0        People & Blogs
#
#       v_length  views_count  v_rating  no_ratings_given  comments_count  \
# 1440     157.0       1537.0       5.0               4.0             3.0
# ...

# %% [markdown]
# #### 2. Find out the 10 most viewed videos and also find the top 5 which video having the most of comments and count?

# %%
df_top_10_views = youtube.sort_values(by='views_count',ascending=False).head(10)
df_top_10_views
# Out:
#              v_id       v_uploader  v_interval        v_category  v_length  \
# 1109  12Z3J1uzd0Q          kaejane       404.0  Film & Animation     615.0
# 3880  4DC4Rb9quKk     ChrisBrownTV       933.0             Music     265.0
# 3690  LU8DDYz68kM         Jason275       807.0    Pets & Animals     503.0
# 1053  kHmvkRoEowc  itschriscrocker       937.0     Entertainment     131.0
# 3876  Md6rURKhZmA      TPainVideos       857.0             Music     240.0
# 1128  EwTZ2xpQwpA        TayZonday       796.0             Music     292.0
# 3886  A2f3cuUXXRs         RKellyTV       751.0             Music     326.0
# 2547  rZBA0SKmQy8      TownIdiot25       848.0            Comedy     130.0
# 969   irp8CNj9qBI      Frozentoast       215.0             Music     349.0
# 4063  ZCYaw5tGYAs         nozzle49       529.0            Comedy      80.0
#
#       views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# ...

# %%
df_top_10_comments = youtube.sort_values(by='comments_count',ascending=False).head(10)
df_top_10_comments
# Out:
#              v_id        v_uploader  v_interval      v_category  v_length  \
# 1053  kHmvkRoEowc   itschriscrocker       937.0   Entertainment     131.0
# 1128  EwTZ2xpQwpA         TayZonday       796.0           Music     292.0
# 3880  4DC4Rb9quKk      ChrisBrownTV       933.0           Music     265.0
# 1763  Qit3ALTelOo          smpfilms       932.0  Pets & Animals     210.0
# 474   UW_1CvDFYVg        mileymandy      1124.0          Comedy     135.0
# 2547  rZBA0SKmQy8       TownIdiot25       848.0          Comedy     130.0
# 870   GfPJeDssBOM   HouseholdHacker       998.0   Howto & Style     205.0
# 969   irp8CNj9qBI       Frozentoast       215.0           Music     349.0
# 34    eBGIQ7ZuuiU  YouGotRickRolled       832.0          Comedy     210.0
# 538   LTxO_pgMqys         machinima       969.0   Entertainment     407.0
#
#       views_count  v_rating  no_ratings_given  comments_count v_ids_related  \
# 1053   18235463.0      2.42          122129.0        259683.0   h863nXDqCM0
# ...

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">2. Read data set(2017.csv)
#
#
# 1. Find the top 10 most generous countries and find top 10 countries with trust in government?
#
# 2A). Find top 10 Countries in Family Satisfaction and also find top 10 Countries with Best Economy?
#
# 2B). Find top 10 Most Freedom Oriented Countries and also Find top 10 Happiest Countries?

# %%
df_2017 = pd.read_csv('2017.csv')

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2017.tail()
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %% [markdown]
# #### 1. Find the top 10 most generous countries and find top 10 countries with trust in government?

# %%
df_top_10_generous = df_2017.sort_values(by='Generosity',ascending=False).head(10)
df_top_10_generous
# Out:
#             Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 113         Myanmar             114            4.545      4.614740
# 80        Indonesia              81            5.262      5.352889
# 26            Malta              27            6.527      6.598397
# 31         Thailand              32            6.424      6.509117
# 7       New Zealand               8            7.314      7.379510
# 151           Syria             152            3.462      3.663669
# 18   United Kingdom              19            6.714      6.783792
# 119       Sri Lanka             120            4.440      4.553447
# 144           Haiti             145            3.603      3.734715
# 9         Australia              10            7.284      7.356651
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 113     4.475260                  0.367111  1.123236
# 80      5.171112                  0.995539  1.274445
# 26      6.455603                  1.343280  1.488412
# ...

# %%
df_top_10_trust = df_2017.sort_values(by='Trust..Government.Corruption.',ascending=False).head(10)
df_top_10_trust
# Out:
#                   Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 25              Singapore              26            6.572      6.636723
# 150                Rwanda             151            3.471      3.543030
# 34                  Qatar              35            6.375      6.568477
# 1                 Denmark               2            7.522      7.581728
# 8                  Sweden               9            7.284      7.344095
# 7             New Zealand               8            7.314      7.379510
# 4                 Finland               5            7.469      7.527542
# 3             Switzerland               4            7.494      7.561772
# 20   United Arab Emirates              21            6.648      6.722047
# 17             Luxembourg              18            6.863      6.923686
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 25      6.507277                  1.692278  1.353814
# 150     3.398970                  0.368746  0.945707
# ...

# %% [markdown]
# #### 2A). Find top 10 Countries in Family Satisfaction and also find top 10 Countries with Best Economy?

# %%
df_top_10_trust = df_2017.sort_values(by='Family',ascending=False).head(10)
df_top_10_trust
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 2       Iceland               3            7.504      7.622030     7.385970
# 14      Ireland              15            6.977      7.043352     6.910649
# 1       Denmark               2            7.522      7.581728     7.462272
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# 7   New Zealand               8            7.314      7.379510     7.248490
# 4       Finland               5            7.469      7.527542     7.410458
# 0        Norway               1            7.537      7.594445     7.479556
# 33        Spain              34            6.403      6.471055     6.334945
# 3   Switzerland               4            7.494      7.561772     7.426227
# 9     Australia              10            7.284      7.356651     7.211349
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df_top_10_trust = df_2017.sort_values(by='Economy..GDP.per.Capita.',ascending=False).head(10)
df_top_10_trust
# Out:
#                     Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 34                    Qatar              35            6.375      6.568477
# 17               Luxembourg              18            6.863      6.923686
# 25                Singapore              26            6.572      6.636723
# 38                   Kuwait              39            6.105      6.191957
# 20     United Arab Emirates              21            6.648      6.722047
# 0                    Norway               1            7.537      7.594445
# 3               Switzerland               4            7.494      7.561772
# 70  Hong Kong S.A.R., China              71            5.472      5.549594
# 13            United States              14            6.993      7.074657
# 14                  Ireland              15            6.977      7.043352
#
#     Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# ...

# %% [markdown]
# #### 2B). Find top 10 Most Freedom Oriented Countries and also Find top 10 Happiest Countries?

# %%
df_top_10_freedom = df_2017.sort_values(by='Freedom',ascending=False).head(10)
df_top_10_freedom
# Out:
#          Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 46    Uzbekistan              47            5.971      6.065538     5.876463
# 0         Norway               1            7.537      7.594445     7.479556
# 128     Cambodia             129            4.168      4.278518     4.057483
# 2        Iceland               3            7.504      7.622030     7.385970
# 1        Denmark               2            7.522      7.581728     7.462272
# 3    Switzerland               4            7.494      7.561772     7.426227
# 4        Finland               5            7.469      7.527542     7.410458
# 7    New Zealand               8            7.314      7.379510     7.248490
# 8         Sweden               9            7.284      7.344095     7.223905
# 6         Canada               7            7.316      7.384403     7.247597
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# ...

# %%
df_top_10_happiness = df_2017.sort_values(by='Happiness.Rank',ascending=False).head(10)
df_top_10_happiness
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 154  Central African Republic             155            2.693      2.864884
# 153                   Burundi             154            2.905      3.074690
# 152                  Tanzania             153            3.349      3.461430
# 151                     Syria             152            3.462      3.663669
# 150                    Rwanda             151            3.471      3.543030
# 149                      Togo             150            3.495      3.594038
# 148                    Guinea             149            3.507      3.584428
# 147                   Liberia             148            3.533      3.653756
# 146               South Sudan             147            3.591      3.725539
# 145                     Yemen             146            3.593      3.692750
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 154     2.521116                  0.000000  0.000000
# ...

# %% [markdown]
# --------

# %% [markdown]
# #  2 Questions X  15 Marks = 30 Marks

# %% [markdown]
# -----------

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;">1. Read the datasets
# - `airport-codes.csv` - this file contains metadata for all aiports in the world.
# - `us_air_transport_stats.csv` - this file contains the stats like number of passengers, amount of freight etc. for each airport origin and destination and each airline carrier.
#
# ### Problem statement
#
# **Exercise:1** You have to create a table that compares the number of passengers flown by each major airline out of each large airports in the US. Our final table should have one row for each airport, and one column for each carrier. We will eventually limit the number of columns by selecting only the large carriers.(Hint: Joins and pivot tables)
#
#
#
# **Exercise:2** Find the passenger count and freight load for each route among the large airports in the US.
#
#
# **Exercise:3**Find the busiest routes for passengers and freights in the US.

# %%
airport_codes = pd.read_csv('airport-codes.csv')

# %%
airport_stats = pd.read_csv('us_air_transport_stats.csv')

# %%
airport_codes.head()
# Out:
#   ident           type                                name  elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport          11.0
# 1  00AA  small_airport                Aero B Ranch Airport        3435.0
# 2  00AK  small_airport                        Lowell Field         450.0
# 3  00AL  small_airport                        Epps Airpark         820.0
# 4  00AR         closed  Newport Hospital & Clinic Heliport         237.0
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0       NaN          US      US-PA      Bensalem      00A       NaN
# 1       NaN          US      US-KS         Leoti     00AA       NaN
# 2       NaN          US      US-AK  Anchor Point     00AK       NaN
# 3       NaN          US      US-AL       Harvest     00AL       NaN
# 4       NaN          US      US-AR       Newport      NaN       NaN
#
#   local_code                            coordinates
# 0        00A     -74.93360137939453, 40.07080078125
# ...

# %%
airport_stats.head()
# Out:
#    PASSENGERS  FREIGHT  MAIL  DISTANCE UNIQUE_CARRIER  AIRLINE_ID CARRIER  \
# 0           0        0     0       156            0MQ     21253.0     0MQ
# 1           0        0     0       110            0MQ     21253.0     0MQ
# 2           0        0     0       949            0WQ     21352.0     0WQ
# 3           0        0     0       725            0WQ     21352.0     0WQ
# 4           0        0     0        18            0WQ     21352.0     0WQ
#
#                             CARRIER_NAME  ORIGIN_AIRPORT_ID ORIGIN  \
# 0  Multi-Aero, Inc. d/b/a Air Choice One            13930.0    ORD
# 1  Multi-Aero, Inc. d/b/a Air Choice One            15016.0    STL
# 2                      Avjet Corporation            10279.0    AMA
# 3                      Avjet Corporation            10372.0    ASE
# 4                      Avjet Corporation            10800.0    BUR
#
#    DEST_AIRPORT_ID DEST  YEAR  MONTH
# 0          11288.0  DEC  2018      9
# 1          11288.0  DEC  2018      9
# ...

# %%
airport_codes.shape
# Out:
# (54736, 12)

# %%
airport_stats.shape
# Out:
# (249170, 14)

# %%
airport_stats.columns
# Out:
# Index(['PASSENGERS', 'FREIGHT', 'MAIL', 'DISTANCE', 'UNIQUE_CARRIER',
#        'AIRLINE_ID', 'CARRIER', 'CARRIER_NAME', 'ORIGIN_AIRPORT_ID', 'ORIGIN',
#        'DEST_AIRPORT_ID', 'DEST', 'YEAR', 'MONTH'],
#       dtype='object')

# %%
airport_codes.columns
# Out:
# Index(['ident', 'type', 'name', 'elevation_ft', 'continent', 'iso_country',
#        'iso_region', 'municipality', 'gps_code', 'iata_code', 'local_code',
#        'coordinates'],
#       dtype='object')

# %%
airport_codes['type'].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
new_airport_codes = airport_codes[(airport_codes['type'] == 'large_airport')\
                                  & (airport_codes['iso_country'] == 'US') ]

# %%
new_airport_codes.drop(columns = ['iso_country', 'type','iso_region','ident','iata_code','local_code','coordinates'],
                       axis = 1, inplace = True)

# %%
new_airport_codes
# Out:
#                                                     name  elevation_ft  \
# 25914                  Albuquerque International Sunport        5355.0
# 25933                             Andrews Air Force Base         280.0
# 25946                        Fort Worth Alliance Airport         722.0
# 25950                     Augusta Regional At Bush Field         144.0
# 25983        Rick Husband Amarillo International Airport        3607.0
# 26035   Hartsfield Jackson Atlanta International Airport        1026.0
# 26044             Austin Bergstrom International Airport         542.0
# 26048                         Asheville Regional Airport        2165.0
# 26072                               Beale Air Force Base         113.0
# 26073                           Barksdale Air Force Base         166.0
# 26090                      Bradley International Airport         173.0
# 26105     Boeing Field King County International Airport          21.0
# ...

# %%
new_airport_codes['name'].nunique()
# Out:
# 170

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#16850c;">Exercise:1  You have to create a table that compares the number of passengers flown by each major airline out of each large airports in the US. Our final table should have one row for each airport, and one column for each carrier. We will eventually limit the number of columns by selecting only the large carriers.

# %%
airport_stats.pivot_table(index='CARRIER_NAME').reset_index()
# Out:
#                                           CARRIER_NAME  AIRLINE_ID  \
# 0                                          40-Mile Air     20342.0
# 1                                          ABX Air Inc     20453.0
# 2                                    ADVANCED AIR, LLC     21894.0
# 3    Aerodynamics Inc. d/b/a SkyValue d/b/a SkyValu...     20354.0
# 4                  Air Charter, Inc d/b/a Air Flamenco     21615.0
# 5                                   Air Excursions LLC     21386.0
# 6                                    Air Sunshine Inc.     19650.0
# 7                          Air Transport International     19874.0
# 8                          Air Wisconsin Airlines Corp     20046.0
# 9                                 Alaska Airlines Inc.     19930.0
# 10                              Alaska Central Express     20341.0
# 11                                       Allegiant Air     20368.0
# 12                                     Aloha Air Cargo     21634.0
# ...

# %%
new_airport_codes.pivot_table(index='name').reset_index()
# Out:
#                                                   name  elevation_ft
# 0                      Abraham Lincoln Capital Airport         598.0
# 1                    Albuquerque International Sunport        5355.0
# 2                                 Altus Air Force Base        1382.0
# 3                               Andrews Air Force Base         280.0
# 4                           Asheville Regional Airport        2165.0
# 5                       Augusta Regional At Bush Field         144.0
# 6               Austin Bergstrom International Airport         542.0
# 7                Austin Straubel International Airport         695.0
# 8    Baltimore/Washington International Thurgood Ma...         146.0
# 9                         Bangor International Airport         192.0
# 10                            Barksdale Air Force Base         166.0
# 11                                Beale Air Force Base         113.0
# 12   Bill & Hillary Clinton National Airport/Adams ...         262.0
# ...

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#16850c;">Exercise:2 Find the passenger count and freight load for each route among the large airports in the US.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#16850c;">Exercise:3Find the busiest routes for passengers and freights in the US.

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#db0b49;"> 2. This data set contains information about 10,000 movies collected from The Movie Database (TMDb). Data set has a information like budget of movie production, revenue, original title,runtime,popularity and release_year.
#
#    1. Drop four column 'homepage,keywords,budget_adj and revenue_adj'. And create a column name is "profit" using the budget and revenue column. And also find the top 10 most profitable and non profitable movies?
#
#    2.  Which movie earn maximum and minimum profit?
#
#    3. Which top 10 movies is Highest in budget and revenue ?

# %%
tmdb_movies = pd.read_csv('tmdb-movies.csv')

# %%
tmdb_movies.shape
# Out:
# (10866, 21)

# %%
tmdb_movies.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
100*tmdb_movies.isnull().sum()/tmdb_movies.shape[0]
# Out:
# id                       0.000000
# imdb_id                  0.092030
# popularity               0.000000
# budget                   0.000000
# revenue                  0.000000
# original_title           0.000000
# cast                     0.699429
# homepage                72.979937
# director                 0.404933
# tagline                 25.989324
# keywords                13.740107
# overview                 0.036812
# runtime                  0.000000
# genres                   0.211669
# production_companies     9.479109
# release_date             0.000000
# vote_count               0.000000
# vote_average             0.000000
# release_year             0.000000
# budget_adj               0.000000
# revenue_adj              0.000000
# dtype: float64

# %%
tmdb_movies.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %% [markdown]
# ####  1. Drop four column 'homepage,keywords,budget_adj and revenue_adj'. And create a column name is "profit" using the budget and revenue column. And also find the top 10 most profitable and non profitable movies?

# %%
tmdb_movies.drop(columns = ['homepage', 'keywords', 'budget_adj', 'revenue_adj'], inplace=True)

# %%
tmdb_movies.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'director', 'tagline', 'overview', 'runtime', 'genres',
#        'production_companies', 'release_date', 'vote_count', 'vote_average',
#        'release_year'],
#       dtype='object')

# %% [markdown]
# #### .Top 10 most profitable and non profitable movies?

# %%
tmdb_movies['profit'] = tmdb_movies['revenue'] - tmdb_movies['budget']

# %%
df_top_10_profitable_movies = tmdb_movies.sort_values(by='profit',ascending=False).head(10)
df_top_10_profitable_movies['original_title']
# Out:
# 1386                                          Avatar
# 3                       Star Wars: The Force Awakens
# 5231                                         Titanic
# 0                                     Jurassic World
# 4                                          Furious 7
# 4361                                    The Avengers
# 3374    Harry Potter and the Deathly Hallows: Part 2
# 14                           Avengers: Age of Ultron
# 5422                                          Frozen
# 8094                                         The Net
# Name: original_title, dtype: object

# %%
df_top_10_non_profitable_movies = tmdb_movies.sort_values(by='profit',ascending=True).head(10)
df_top_10_non_profitable_movies['original_title']
# Out:
# 2244       The Warrior's Way
# 5508         The Lone Ranger
# 2069             The Wolfman
# 2214             The Pacific
# 7031               The Alamo
# 3484         Mars Needs Moms
# 2190          Double Wedding
# 1696    Dragonball Evolution
# 4970            Brother Bear
# 2435        The 13th Warrior
# Name: original_title, dtype: object

# %% [markdown]
# #### 2). Which movie earn maximum and minimum profit and write your observation?

# %%
df_top_1_profitable_movies = tmdb_movies.sort_values(by='profit',ascending=False).head(1)
df_top_1_profitable_movies
# Out:
#          id    imdb_id  popularity     budget     revenue original_title  \
# 1386  19995  tt0499549    9.432768  237000000  2781505847         Avatar
#
#                                                    cast       director  \
# 1386  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...  James Cameron
#
#                           tagline  \
# 1386  Enter the World of Pandora.
#
#                                                overview  runtime  \
# 1386  In the 22nd century, a paraplegic Marine is di...      162
#
#                                         genres  \
# 1386  Action|Adventure|Fantasy|Science Fiction
#
#                                    production_companies release_date  \
# 1386  Ingenious Film Partners|Twentieth Century Fox ...     12/10/09
#
#       vote_count  vote_average  release_year      profit
# 1386        8458           7.1          2009  2544505847

# %%
df_top_1_non_profitable_movies = tmdb_movies.sort_values(by='profit',ascending=True).head(1)
df_top_1_non_profitable_movies
# Out:
#          id    imdb_id  popularity     budget   revenue     original_title  \
# 2244  46528  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                    cast    director  \
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                       tagline  \
# 2244  Assassin. Hero. Legend.
#
#                                                overview  runtime  \
# 2244  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                          genres      production_companies  \
# 2244  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#      release_date  vote_count  vote_average  release_year     profit
# 2244      12/2/10          74           6.4          2010 -413912431

# %% [markdown]
# ### Observations

# %% [markdown]
# ### Avatar is highest profitable and The Warrior's Way is least profitable. High profitable movies has high popularity and high revenue

# %% [markdown]
# #### 3. Which top 10 movies is Highest in budget and revenue ?

# %%
df_top_10_hghest_budjet_movies = tmdb_movies.sort_values(by=['budget','revenue'],ascending=False).head(10)
df_top_10_hghest_budjet_movies['original_title']
# Out:
# 2244                              The Warrior's Way
# 3375    Pirates of the Caribbean: On Stranger Tides
# 7387       Pirates of the Caribbean: At World's End
# 14                          Avengers: Age of Ultron
# 6570                               Superman Returns
# 1929                                        Tangled
# 4411                                    John Carter
# 7394                                   Spider-Man 3
# 5508                                The Lone Ranger
# 4363                          The Dark Knight Rises
# Name: original_title, dtype: object
